# %% [markdown]
# # Data PreProcessing

# %% [raw]
# # 1)Impoting the required Libraries/Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('MiningProcess_Flotation_Plant_Database.csv')

# %% [markdown]
# # 2)Understanding the Data

# %%
dataset.shape
# Out:
# (737453, 24)

# %%
dataset.dtypes
# Out:
# date                            object
# % Iron Feed                     object
# % Silica Feed                   object
# Starch Flow                     object
# Amina Flow                      object
# Ore Pulp Flow                   object
# Ore Pulp pH                     object
# Ore Pulp Density                object
# Flotation Column 01 Air Flow    object
# Flotation Column 02 Air Flow    object
# Flotation Column 03 Air Flow    object
# Flotation Column 04 Air Flow    object
# Flotation Column 05 Air Flow    object
# Flotation Column 06 Air Flow    object
# Flotation Column 07 Air Flow    object
# Flotation Column 01 Level       object
# Flotation Column 02 Level       object
# Flotation Column 03 Level       object
# Flotation Column 04 Level       object
# Flotation Column 05 Level       object
# Flotation Column 06 Level       object
# Flotation Column 07 Level       object
# % Iron Concentrate              object
# % Silica Concentrate            object
# dtype: object

# %%
dataset.head()
# Out:
#                   date % Iron Feed % Silica Feed Starch Flow Amina Flow  \
# 0  2017-03-10 01:00:00        55,2         16,98     3019,53    557,434
# 1  2017-03-10 01:00:00        55,2         16,98     3024,41    563,965
# 2  2017-03-10 01:00:00        55,2         16,98     3043,46    568,054
# 3  2017-03-10 01:00:00        55,2         16,98     3047,36    568,665
# 4  2017-03-10 01:00:00        55,2         16,98     3033,69    558,167
#
#   Ore Pulp Flow Ore Pulp pH Ore Pulp Density Flotation Column 01 Air Flow  \
# 0       395,713     10,0664             1,74                      249,214
# 1       397,383     10,0672             1,74                      249,719
# 2       399,668      10,068             1,74                      249,741
# 3       397,939     10,0689             1,74                      249,917
# 4       400,254     10,0697             1,74                      250,203
#
#   Flotation Column 02 Air Flow  ... Flotation Column 07 Air Flow  \
# ...

# %%
dataset.tail()
# Out:
#                        date % Iron Feed % Silica Feed Starch Flow Amina Flow  \
# 737448  2017-09-09 23:00:00       49,75          23,2     2710,94    441,052
# 737449  2017-09-09 23:00:00       49,75          23,2     2692,01    473,436
# 737450  2017-09-09 23:00:00       49,75          23,2      2692,2    500,488
# 737451  2017-09-09 23:00:00       49,75          23,2     1164,12    491,548
# 737452  2017-09-09 23:00:00       49,75          23,2     1164,12    468,019
#
#        Ore Pulp Flow Ore Pulp pH Ore Pulp Density  \
# 737448        386,57     9,62129          1,65365
# 737449       384,939     9,62063          1,65352
# 737450       383,496     9,61874          1,65338
# 737451       384,976     9,61686          1,65324
# 737452       384,801     9,61497           1,6531
#
#        Flotation Column 01 Air Flow Flotation Column 02 Air Flow  ...  \
# 737448                      302,344                      298,786  ...
# ...

# %%
dataset.columns.values 
#returns an array of column names
# Out:
# array(['date', '% Iron Feed', '% Silica Feed', 'Starch Flow',
#        'Amina Flow', 'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density',
#        'Flotation Column 01 Air Flow', 'Flotation Column 02 Air Flow',
#        'Flotation Column 03 Air Flow', 'Flotation Column 04 Air Flow',
#        'Flotation Column 05 Air Flow', 'Flotation Column 06 Air Flow',
#        'Flotation Column 07 Air Flow', 'Flotation Column 01 Level',
#        'Flotation Column 02 Level', 'Flotation Column 03 Level',
#        'Flotation Column 04 Level', 'Flotation Column 05 Level',
#        'Flotation Column 06 Level', 'Flotation Column 07 Level',
#        '% Iron Concentrate', '% Silica Concentrate'], dtype=object)

# %%
dataset.columns.values.tolist()
#returns a list of column names
# Out:
# ['date',
#  '% Iron Feed',
#  '% Silica Feed',
#  'Starch Flow',
#  'Amina Flow',
#  'Ore Pulp Flow',
#  'Ore Pulp pH',
#  'Ore Pulp Density',
#  'Flotation Column 01 Air Flow',
#  'Flotation Column 02 Air Flow',
#  'Flotation Column 03 Air Flow',
#  'Flotation Column 04 Air Flow',
#  'Flotation Column 05 Air Flow',
#  'Flotation Column 06 Air Flow',
#  'Flotation Column 07 Air Flow',
#  'Flotation Column 01 Level',
#  'Flotation Column 02 Level',
#  'Flotation Column 03 Level',
#  'Flotation Column 04 Level',
#  'Flotation Column 05 Level',
#  'Flotation Column 06 Level',
#  'Flotation Column 07 Level',
#  '% Iron Concentrate',
#  '% Silica Concentrate']

# %% [markdown]
# # 3)CHECK FOR THE MISSING VALUES

# %%
dataset.isnull().any()
# Out:
# date                            False
# % Iron Feed                     False
# % Silica Feed                   False
# Starch Flow                     False
# Amina Flow                      False
# Ore Pulp Flow                   False
# Ore Pulp pH                     False
# Ore Pulp Density                False
# Flotation Column 01 Air Flow    False
# Flotation Column 02 Air Flow    False
# Flotation Column 03 Air Flow    False
# Flotation Column 04 Air Flow    False
# Flotation Column 05 Air Flow    False
# Flotation Column 06 Air Flow    False
# Flotation Column 07 Air Flow    False
# Flotation Column 01 Level       False
# Flotation Column 02 Level       False
# Flotation Column 03 Level       False
# Flotation Column 04 Level       False
# Flotation Column 05 Level       False
# Flotation Column 06 Level       False
# Flotation Column 07 Level       False
# % Iron Concentrate              False
# % Silica Concentrate            False
# dtype: bool

# %%
dataset.isna().sum()
# Out:
# date                            0
# % Iron Feed                     0
# % Silica Feed                   0
# Starch Flow                     0
# Amina Flow                      0
# Ore Pulp Flow                   0
# Ore Pulp pH                     0
# Ore Pulp Density                0
# Flotation Column 01 Air Flow    0
# Flotation Column 02 Air Flow    0
# Flotation Column 03 Air Flow    0
# Flotation Column 04 Air Flow    0
# Flotation Column 05 Air Flow    0
# Flotation Column 06 Air Flow    0
# Flotation Column 07 Air Flow    0
# Flotation Column 01 Level       0
# Flotation Column 02 Level       0
# Flotation Column 03 Level       0
# Flotation Column 04 Level       0
# Flotation Column 05 Level       0
# Flotation Column 06 Level       0
# Flotation Column 07 Level       0
# % Iron Concentrate              0
# % Silica Concentrate            0
# dtype: int64

# %% [markdown]
# # Drop Duplicate Data

# %%
dataset.drop_duplicates(inplace=True)
#remove duplicates if present,modify the original data accordingly

# %%
dataset.shape
# Out:
# (736282, 24)

# %% [markdown]
# # Data Visualization

# %%
dataset.drop(['date'],axis=1,inplace=True)

# %%
for column in dataset.columns:
    dataset[column] = dataset[column].apply(lambda x: x.replace(',', '.'))

# %%
dataset
# Out:
#        % Iron Feed % Silica Feed Starch Flow Amina Flow Ore Pulp Flow  \
# 0             55.2         16.98     3019.53    557.434       395.713
# 1             55.2         16.98     3024.41    563.965       397.383
# 2             55.2         16.98     3043.46    568.054       399.668
# 3             55.2         16.98     3047.36    568.665       397.939
# 4             55.2         16.98     3033.69    558.167       400.254
# ...            ...           ...         ...        ...           ...
# 737448       49.75          23.2     2710.94    441.052        386.57
# 737449       49.75          23.2     2692.01    473.436       384.939
# 737450       49.75          23.2      2692.2    500.488       383.496
# 737451       49.75          23.2     1164.12    491.548       384.976
# 737452       49.75          23.2     1164.12    468.019       384.801
#
#        Ore Pulp pH Ore Pulp Density Flotation Column 01 Air Flow  \
# ...

# %%
dataset['% Iron Feed']=pd.to_numeric(dataset['% Iron Feed'],errors='coerce')
dataset['% Silica Feed']=pd.to_numeric(dataset['% Silica Feed'],errors='coerce')
dataset['Starch Flow']=pd.to_numeric(dataset['Starch Flow'],errors='coerce')
dataset['Amina Flow']=pd.to_numeric(dataset['Amina Flow'],errors='coerce')
dataset['Ore Pulp Flow']=pd.to_numeric(dataset['Ore Pulp Flow'],errors='coerce')
dataset['Ore Pulp pH']=pd.to_numeric(dataset['Ore Pulp pH'],errors='coerce')
dataset['Ore Pulp Density']=pd.to_numeric(dataset['Ore Pulp Density'],errors='coerce')
dataset['Flotation Column 01 Air Flow']=pd.to_numeric(dataset['Flotation Column 01 Air Flow'],errors='coerce')
dataset['Flotation Column 02 Air Flow']=pd.to_numeric(dataset['Flotation Column 02 Air Flow'],errors='coerce')
dataset['Flotation Column 03 Air Flow']=pd.to_numeric(dataset['Flotation Column 03 Air Flow'],errors='coerce')
dataset['Flotation Column 04 Air Flow']=pd.to_numeric(dataset['Flotation Column 04 Air Flow'],errors='coerce')
dataset['Flotation Column 05 Air Flow']=pd.to_numeric(dataset['Flotation Column 05 Air Flow'],errors='coerce')
dataset['Flotation Column 06 Air Flow']=pd.to_numeric(dataset['Flotation Column 06 Air Flow'],errors='coerce')
dataset['Flotation Column 07 Air Flow']=pd.to_numeric(dataset['Flotation Column 07 Air Flow'],errors='coerce')
dataset['Flotation Column 01 Level']=pd.to_numeric(dataset['Flotation Column 01 Level'],errors='coerce')
dataset['Flotation Column 02 Level']=pd.to_numeric(dataset['Flotation Column 02 Level'],errors='coerce')
dataset['Flotation Column 03 Level']=pd.to_numeric(dataset['Flotation Column 03 Level'],errors='coerce')
dataset['Flotation Column 04 Level']=pd.to_numeric(dataset['Flotation Column 04 Level'],errors='coerce')
dataset['Flotation Column 05 Level']=pd.to_numeric(dataset['Flotation Column 05 Level'],errors='coerce')
dataset['Flotation Column 06 Level']=pd.to_numeric(dataset['Flotation Column 06 Level'],errors='coerce')
dataset['Flotation Column 07 Level']=pd.to_numeric(dataset['Flotation Column 07 Level'],errors='coerce')
dataset['% Iron Concentrate']=pd.to_numeric(dataset['% Iron Concentrate'],errors='coerce')
dataset['% Silica Concentrate']=pd.to_numeric(dataset['% Silica Concentrate'],errors='coerce')

# %%
dataset.corr()
# Out:
#                               % Iron Feed  % Silica Feed  Starch Flow  \
# % Iron Feed                      1.000000      -0.971876     0.027869
# % Silica Feed                   -0.971876       1.000000    -0.016089
# Starch Flow                      0.027869      -0.016089     1.000000
# Amina Flow                      -0.088128       0.078553     0.254749
# Ore Pulp Flow                    0.161138      -0.151053     0.042962
# Ore Pulp pH                      0.007687       0.008033     0.263497
# Ore Pulp Density                -0.125657       0.104287     0.225990
# Flotation Column 01 Air Flow    -0.061945       0.091544     0.191501
# Flotation Column 02 Air Flow    -0.169021       0.182428     0.187065
# Flotation Column 03 Air Flow    -0.061783       0.083975     0.183637
# Flotation Column 04 Air Flow    -0.137072       0.160606     0.093660
# Flotation Column 05 Air Flow     0.121718      -0.130858    -0.088208
# ...

# %%
plt.figure(figsize=(30, 25))
p = sns.heatmap(dataset.corr(), annot=True)

# %%
silic_corr = dataset.corr()['% Silica Concentrate']
silic_corr = abs(silic_corr).sort_values()
silic_corr
# Out:
# Flotation Column 04 Air Flow    0.004770
# Ore Pulp Flow                   0.008497
# Flotation Column 05 Air Flow    0.008930
# Flotation Column 03 Level       0.014843
# Flotation Column 01 Level       0.017859
# Flotation Column 02 Level       0.031790
# Ore Pulp Density                0.047002
# Flotation Column 06 Air Flow    0.049692
# Starch Flow                     0.066813
# Flotation Column 07 Air Flow    0.071685
# % Silica Feed                   0.072676
# % Iron Feed                     0.077179
# Flotation Column 06 Level       0.102115
# Flotation Column 07 Level       0.140819
# Ore Pulp pH                     0.147211
# Flotation Column 04 Level       0.148886
# Amina Flow                      0.156981
# Flotation Column 02 Air Flow    0.167259
# Flotation Column 05 Level       0.168466
# Flotation Column 03 Air Flow    0.218834
# Flotation Column 01 Air Flow    0.219076
# % Iron Concentrate              0.800598
# % Silica Concentrate            1.000000
# ...

# %%
drop_index= silic_corr.index[:5].tolist()

# %% [markdown]
# Above plot shows the correaltions between the features. From the list we can find out the features which affects the % Silica Concentrate the most and discard the least important ones

# %%
dataset= dataset.drop(drop_index, axis=1)

# %%
dataset.head()
# Out:
#    % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  Ore Pulp pH  \
# 0         55.2          16.98      3019.53     557.434      10.0664
# 1         55.2          16.98      3024.41     563.965      10.0672
# 2         55.2          16.98      3043.46     568.054      10.0680
# 3         55.2          16.98      3047.36     568.665      10.0689
# 4         55.2          16.98      3033.69     558.167      10.0697
#
#    Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0              1.74                       249.214
# 1              1.74                       249.719
# 2              1.74                       249.741
# 3              1.74                       249.917
# 4              1.74                       250.203
#
#    Flotation Column 02 Air Flow  Flotation Column 03 Air Flow  \
# 0                       253.235                       250.576
# 1                       250.532                       250.862
# ...

# %% [markdown]
# SEPARATING DEPENDENT AND INDEPENDENT VARIABLES

# %%
target = '% Silica Concentrate'

y = dataset[target]

# %%
x = dataset.drop([target], axis=1).values

# %%
x.shape
# Out:
# (736282, 17)

# %%
y.shape
# Out:
# (736282,)

# %% [markdown]
# # #Splitting Train and Test Data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (589025, 17)

# %%
x_test.shape
# Out:
# (147257, 17)

# %%
y_train.shape
# Out:
# (589025,)

# %%
y_test.shape
# Out:
# (147257,)

# %% [markdown]
# # Building Model

# %% [markdown]
# 1)LINEAR REGRESSION
#
# from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.predict(x_test)#predicted output
# Out:
# array([2.49590286, 2.26518985, 3.59610543, ..., 3.82210623, 1.97165185,
#        2.80754925])

# %%
y_test#actual output
# Out:
# 425225    2.040000
# 63345     2.140000
# 40251     3.110000
# 534904    2.210000
# 554545    4.394827
#             ...
# 606950    1.660000
# 486710    1.510000
# 605234    5.520000
# 544554    1.440000
# 444750    1.960000
# Name: % Silica Concentrate, Length: 147257, dtype: float64

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,lr.predict(x_test))#testing accuracy
# Out:
# 0.6737231443563728

# %% [markdown]
# From this we observed LinearRegression has given accuracy of 67% which is not much,so we try another model for better accuracy

# %% [markdown]
# 2)Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures()

# %%
x_poly=poly.fit_transform(x)

# %%
x_poly
# Out:
# array([[1.00000000e+00, 5.52000000e+01, 1.69800000e+01, ...,
#         2.73888942e+05, 3.50169470e+04, 4.47694810e+03],
#        [1.00000000e+00, 5.52000000e+01, 1.69800000e+01, ...,
#         2.48078706e+05, 3.33261982e+04, 4.47694810e+03],
#        [1.00000000e+00, 5.52000000e+01, 1.69800000e+01, ...,
#         2.10283693e+05, 3.06827180e+04, 4.47694810e+03],
#        ...,
#        [1.00000000e+00, 4.97500000e+01, 2.32000000e+01, ...,
#         1.87601597e+05, 2.78372651e+04, 4.13063290e+03],
#        [1.00000000e+00, 4.97500000e+01, 2.32000000e+01, ...,
#         1.88326489e+05, 2.78909948e+04, 4.13063290e+03],
#        [1.00000000e+00, 4.97500000e+01, 2.32000000e+01, ...,
#         1.94641557e+05, 2.83547671e+04, 4.13063290e+03]])

# %%
x_poly.shape
# Out:
# (736282, 171)

# %%
lr.fit(x_poly,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lr.predict(x_poly)

# %%
r2_score(y,y_pred)
# Out:
# 0.7262393729400525

# %% [markdown]
# From this we observed PolyRegression has given accuracy of 72% which is not much,so we try another model for better accuracy

# %% [markdown]
# 3)Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor(random_state=0)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
y_pred2=dt.predict(x_test)

# %%
y_pred2
# Out:
# array([2.04, 2.14, 3.11, ..., 5.52, 1.44, 1.96])

# %%
y_test
# Out:
# 425225    2.040000
# 63345     2.140000
# 40251     3.110000
# 534904    2.210000
# 554545    4.394827
#             ...
# 606950    1.660000
# 486710    1.510000
# 605234    5.520000
# 544554    1.440000
# 444750    1.960000
# Name: % Silica Concentrate, Length: 147257, dtype: float64

# %%
r2_score(y_test,y_pred2)
# Out:
# 0.9951494719063148

# %% [markdown]
# We obtained 99.5% accuracy which is really high.Hence we can consider this model to be accurate and implement it.

# %%
plt.figure()
plt.scatter(x=x_test[:,1],y=y_test,color="blue")
plt.scatter(x=x_test[:,1],y=y_pred2,color="red")  
plt.show()

# %%
//from sklearn.externals.six import StringIO
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
